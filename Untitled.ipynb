# %%
# %matplotlib inline
import json
import cv2
import matplotlib.pyplot as plt
from pprint import pprint
import numpy as np

# %%
def frameCounter(file):
    fvs = cv2.VideoCapture(file)
    
    success, frame = fvs.read()
    
    count = 0
    
    while success:
        count += 1
#         cv2.imshow("Video", frame)
#         if cv2.waitKey(500) & 0xFF == ord('q'):
#             break
        
        success, frame = fvs.read()
#         print(count)
        
#     cv2.destroyAllWindows()
    
    return count

# %%
frameCounter('With_ID/ID_track_DS1.avi')
# Out:
# 4440

# %%
plotSkeleton(DS3_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-04561edc9d03> in <module>()
# ----> 1 plotSkeleton(DS3_data)
#
# <ipython-input-14-e7a9317c9b7d> in plotSkeleton(data)
#      14         if len(data[frame]) != 0:
#      15             for body_part in data[frame]["0"]:
# ---> 16                 plt.scatter(data[frame]["0"][body_part][0], 1920 - data[frame]["0"][body_part][1])
#      17         plt.pause(0.02)
#      18
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
# ...

# %%
x = ['Punches', 'Jumping Jack', 'Chests', 'Squats', 'Biceps']
y = [177, 136, 92, 49, 67]
z= [46.1, 51.2, 78.7, 84.6, 91.1]

# %%
fig, ax = plt.subplots()
ax.bar(x, y, align='center', alpha=0.5, label = 'Average Repetition')
ax.scatter(x, z, color = 'r')
ax.plot(x, z, label = 'Average Precision (%)', color = 'r')
ax.set(xlabel = "Exercise")
ax.legend()
fig.savefig("Average Precision and Repetition.png")
