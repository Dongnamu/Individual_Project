# %%
import cv2
from matplotlib import pyplot as plt

# %%
fvs = cv2.VideoCapture('People Only.avi')

for i in range():
    success, frame = fvs.read()
    
fvs.release()

# %%
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
plt.axis('off')
plt.imshow(frame)
cv2.imwrite('pre-openpose.png', frame)
# Out:
# True

# %%
fvs = cv2.VideoCapture('result.mp4')

for i in range(6):
    success, frame2 = fvs.read()
    
fvs.release()

# %%
frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2RGB)

# %%
plt.axis('off')
plt.imshow(frame2)
cv2.imwrite('openpose_error.png', frame2)
# Out:
# True
